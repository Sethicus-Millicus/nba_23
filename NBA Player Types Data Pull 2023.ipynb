# %%
import pandas as pd
import gspread
from google.oauth2.service_account import Credentials
pd.set_option("display.max_columns", None)
import seaborn as sns
import numpy as np
from ast import literal_eval
from datetime import date, timedelta
from scipy import stats
import matplotlib.pyplot as plt
#from sklearn.feature_selection import SelectKBest, mutual_info_regression, f_regression
#from sklearn.ensemble import RandomForestRegressor
import time, os
from bs4 import BeautifulSoup
import re
import datetime as dt
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException
from google.oauth2 import service_account
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select

# %%
# selenium 4
#from selenium import webdriver
#from selenium.webdriver.chrome.service import Service as ChromeService
#from webdriver_manager.chrome import ChromeDriverManager

#web_driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

from selenium import webdriver
#from webdriver_manager.safari import SafariDriverManager

#safaridriver = "/usr/local/bin/safari"
#os.environ['webdriver.safari.driver'] = safaridriver
web_driver = webdriver.Safari()

# %%
td = (dt.date.today() - dt.timedelta(days=1)).strftime("%Y-%m-%d")

# %%
iso=[]
    #soup = BeautifulSoup(web_driver.page_source, 'html.parser')
#web_driver = webdriver.Chrome()
bet_search =  f'https://www.nba.com/stats/players/isolation?TypeGrouping=offensive&PerMode=Totals'
web_driver.get(bet_search)
time.sleep(7)
web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select").click()
x = Select(web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select"))
time.sleep(2)
x.select_by_visible_text("All")
soup = BeautifulSoup(web_driver.page_source, 'html.parser')
tab = soup.find("table",{"class":"Crom_table__p1iZz"})
df = pd.read_html(str(tab))[0]
#df['GAME_DATE'] = y + "-" + m + "-" + da
#print(y+m+da)
iso.append(df)

# %%
iso_df = pd.concat(iso)
iso_df
# Out:
#                       PLAYER TEAM  GP  Poss  Freq%   PPP  PTS  FGM  FGA   FG%  \
# 0                Luka Doncic  DAL  52   378   23.2  1.12  422  139  306  45.4
# 1    Shai Gilgeous-Alexander  OKC  58   341   22.7  1.17  399  136  269  50.6
# 2               Jayson Tatum  BOS  55   335   24.8  1.07  359  127  286  44.4
# 3               James Harden  LAC  53   214   25.2  1.15  245   58  153  37.9
# 4            Anthony Edwards  MIN  57   250   17.2  0.96  241   83  197  42.1
# ..                       ...  ...  ..   ...    ...   ...  ...  ...  ...   ...
# 195          Dennis Schroder  BKN   8    11   10.0  0.46    5    2    9  22.2
# 196               GG Jackson  MEM  27    13    4.4  0.39    5    1   10  10.0
# 197               RJ Barrett  NYK  25    14    3.0  0.36    5    2   13  15.4
# 198         Bojan Bogdanovic  NYK   7    10   11.0  0.40    4    2    9  22.2
# 199         Patrick Williams  CHI  43    14    3.1  0.29    4    2   12  16.7
#
#      eFG%  FT Freq%  TOV Freq%  SF Freq%  And One Freq%  Score Freq%  \
# 0    53.1      18.3        4.5      16.7            3.7         50.0
# 1    54.1      19.9        5.3      16.1            4.1         55.4
# 2    52.6      11.6        6.3      10.1            3.3         46.0
# 3    48.7      21.0        8.9      19.6            1.4         46.7
# 4    48.5      13.2       10.4      12.4            2.4         44.0
# ..    ...       ...        ...       ...            ...          ...
# 195  27.8       0.0       18.2       0.0            0.0         18.2
# 196  10.0      15.4        7.7      15.4            0.0         23.1
# 197  15.4       7.1        7.1       7.1            7.1         14.3
# 198  22.2       0.0       10.0       0.0            0.0         20.0
# 199  16.7       0.0       14.3       0.0            0.0         14.3
#
#      Percentile
# 0          85.4
# 1          92.5
# 2          77.4
# 3          89.9
# 4          55.3
# ..          ...
# 195         3.0
# 196         1.5
# 197         1.0
# 198         2.0
# 199         0.0
#
# [200 rows x 17 columns]

# %%
iso_df = pd.concat(iso)
iso_df['As of'] = td
iso_prior = pd.read_csv('iso_23.csv')
iso_df2 = pd.concat([iso_prior,iso_df]).drop_duplicates(subset=['PLAYER','GP','Poss'])
iso_df2.to_csv('iso_23.csv')
iso_df.to_csv('iso_23_today.csv')

# %%
transition=[]
    #soup = BeautifulSoup(web_driver.page_source, 'html.parser')
web_driver.quit()
web_driver = webdriver.Safari()
bet_search =  f'https://www.nba.com/stats/players/transition?PerMode=Totals'
web_driver.get(bet_search)
time.sleep(7)
web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select").click()
x = Select(web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select"))
time.sleep(2)
x.select_by_visible_text("All")
soup = BeautifulSoup(web_driver.page_source, 'html.parser')
tab = soup.find("table",{"class":"Crom_table__p1iZz"})
df = pd.read_html(str(tab))[0]
#df['GAME_DATE'] = y + "-" + m + "-" + da
#print(y+m+da)
transition.append(df)

# %%
transition_df = pd.concat(transition)
transition_df['As of'] = td
transition_prior = pd.read_csv('transition_23.csv')
transition_df2 = pd.concat([transition_prior,transition_df]).drop_duplicates().drop_duplicates(subset=['PLAYER','GP','Poss'])
transition_df2.to_csv('transition_23.csv')
transition_df.to_csv('transition_23_today.csv')

# %%
ballhandler=[]
    #soup = BeautifulSoup(web_driver.page_source, 'html.parser')
web_driver.quit()
web_driver = webdriver.Safari()
bet_search =  f'https://www.nba.com/stats/players/ball-handler?PerMode=Totals'
web_driver.get(bet_search)
time.sleep(7)
web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select").click()
x = Select(web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select"))
time.sleep(2)
x.select_by_visible_text("All")
soup = BeautifulSoup(web_driver.page_source, 'html.parser')
tab = soup.find("table",{"class":"Crom_table__p1iZz"})
df = pd.read_html(str(tab))[0]
#df['GAME_DATE'] = y + "-" + m + "-" + da
#print(y+m+da)
ballhandler.append(df)

# %%
ballhandler_df = pd.concat(ballhandler)
ballhandler_df['As of'] = td
ballhandler_prior = pd.read_csv('ballhandler_23.csv')
ballhandler_df2 = pd.concat([ballhandler_prior,ballhandler_df]).drop_duplicates(subset=['PLAYER','GP','Poss'])
ballhandler_df2.to_csv('ballhandler_23.csv')
ballhandler_df.to_csv('ballhandler_23_today.csv')

# %%
rollman=[]
    #soup = BeautifulSoup(web_driver.page_source, 'html.parser')
web_driver.quit()
web_driver = webdriver.Safari()
bet_search =  f'https://www.nba.com/stats/players/roll-man?PerMode=Totals'
web_driver.get(bet_search)
time.sleep(7)
web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select").click()
x = Select(web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select"))
time.sleep(2)
x.select_by_visible_text("All")
soup = BeautifulSoup(web_driver.page_source, 'html.parser')
tab = soup.find("table",{"class":"Crom_table__p1iZz"})
df = pd.read_html(str(tab))[0]
#df['GAME_DATE'] = y + "-" + m + "-" + da
#print(y+m+da)
rollman.append(df)

# %%
rollman_df = pd.concat(rollman)
rollman_df['As of'] = td
rollman_prior = pd.read_csv('rollman_23.csv')
rollman_df2 = pd.concat([rollman_prior,rollman_df]).drop_duplicates(subset=['PLAYER','GP','Poss'])
rollman_df2.to_csv('rollman_23.csv')
rollman_df.to_csv('rollman_23_today.csv')

# %%
#https://www.nba.com/stats/players/playtype-post-up?PerMode=Totals
    
    
postup=[]
    #soup = BeautifulSoup(web_driver.page_source, 'html.parser')
web_driver.quit()
web_driver = webdriver.Safari()
bet_search =  f'https://www.nba.com/stats/players/playtype-post-up?PerMode=Totals'
web_driver.get(bet_search)
time.sleep(7)
try:
    web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select").click()
    x = Select(web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select"))
    time.sleep(2)
    x.select_by_visible_text("All")
except:
    pass
soup = BeautifulSoup(web_driver.page_source, 'html.parser')
tab = soup.find("table",{"class":"Crom_table__p1iZz"})
df = pd.read_html(str(tab))[0]

#df['GAME_DATE'] = y + "-" + m + "-" + da
#print(y+m+da)
postup.append(df)

# %%
postup_df = pd.concat(postup)
postup_df['As of'] = td
postup_prior = pd.read_csv('postup_23.csv')
postup_df2 = pd.concat([postup_prior,postup_df]).drop_duplicates(subset=['PLAYER','GP','Poss'])
postup_df2.to_csv('postup_23.csv')
postup_df.to_csv('postup_23_today.csv')

# %%
    
    
handoff=[]
    #soup = BeautifulSoup(web_driver.page_source, 'html.parser')
web_driver.quit()
web_driver = webdriver.Safari()
bet_search =  f'https://www.nba.com/stats/players/hand-off?PerMode=Totals'
web_driver.get(bet_search)
time.sleep(7)
try:
    web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select").click()
    x = Select(web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select"))
    time.sleep(2)
    x.select_by_visible_text("All")
except:
    pass
soup = BeautifulSoup(web_driver.page_source, 'html.parser')
tab = soup.find("table",{"class":"Crom_table__p1iZz"})
df = pd.read_html(str(tab))[0]
#df['GAME_DATE'] = y + "-" + m + "-" + da
#print(y+m+da)
handoff.append(df)

# %%
handoff_df = pd.concat(handoff)
handoff_df['As of'] = td
handoff_prior = pd.read_csv('handoff_23.csv')
handoff_df2 = pd.concat([handoff_prior,handoff_df]).drop_duplicates(subset=['PLAYER','GP','Poss'])
handoff_df2.to_csv('handoff_23.csv')
handoff_df.to_csv('handoff_23_today.csv')

# %%
    
cut=[]
    #soup = BeautifulSoup(web_driver.page_source, 'html.parser')
web_driver.quit()
web_driver = webdriver.Safari()
bet_search =  f'https://www.nba.com/stats/players/cut?PerMode=Totals'
web_driver.get(bet_search)
time.sleep(7)
try:
    web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select").click()
    x = Select(web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select"))
    time.sleep(2)
    x.select_by_visible_text("All")
except:
    pass
soup = BeautifulSoup(web_driver.page_source, 'html.parser')
tab = soup.find("table",{"class":"Crom_table__p1iZz"})
df = pd.read_html(str(tab))[0]
#df['GAME_DATE'] = y + "-" + m + "-" + da
#print(y+m+da)
cut.append(df)

# %%
cut_df = pd.concat(cut)
cut_df['As of'] = td
cut_prior = pd.read_csv('cut_23.csv')
cut_df2 = pd.concat([cut_prior,cut_df]).drop_duplicates(subset=['PLAYER','GP','Poss'])
cut_df2.to_csv('cut_23.csv')
cut_df.to_csv('cut_23_today.csv')

# %%
    
offscreen=[]
    #soup = BeautifulSoup(web_driver.page_source, 'html.parser')
#web_driver.quit()
#web_driver = webdriver.Safari()
bet_search =  f'https://www.nba.com/stats/players/off-screen?PerMode=Totals'
web_driver.get(bet_search)
time.sleep(7)
try:
    web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select").click()
    x = Select(web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select"))
    time.sleep(2)
    x.select_by_visible_text("All")
except:
    pass
soup = BeautifulSoup(web_driver.page_source, 'html.parser')
tab = soup.find("table",{"class":"Crom_table__p1iZz"})
df = pd.read_html(str(tab))[0]
#df['GAME_DATE'] = y + "-" + m + "-" + da
#print(y+m+da)
offscreen.append(df)

# %%
offscreen_df = pd.concat(offscreen)
offscreen_df['As of'] = td
offscreen_prior = pd.read_csv('offscreen_23.csv')
offscreen_df2 = pd.concat([offscreen_prior,offscreen_df]).drop_duplicates(subset=['PLAYER','GP','Poss'])
offscreen_df2.to_csv('offscreen_23.csv')
offscreen_df.to_csv('offscreen_23_today.csv')

# %%
    
putbacks=[]
    #soup = BeautifulSoup(web_driver.page_source, 'html.parser')
web_driver.quit()
web_driver = webdriver.Safari()
bet_search =  f'https://www.nba.com/stats/players/putbacks?PerMode=Totals'
web_driver.get(bet_search)
time.sleep(7)
try:
    web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select").click()
    x = Select(web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select"))
    time.sleep(2)
    x.select_by_visible_text("All")
except:
    pass
soup = BeautifulSoup(web_driver.page_source, 'html.parser')
tab = soup.find("table",{"class":"Crom_table__p1iZz"})
df = pd.read_html(str(tab))[0]
#df['GAME_DATE'] = y + "-" + m + "-" + da
#print(y+m+da)
putbacks.append(df)

# %%
putbacks_df = pd.concat(putbacks)
putbacks_df['As of'] = td
putbacks_prior = pd.read_csv('putbacks_23.csv')
putbacks_df2 = pd.concat([putbacks_prior,putbacks_df]).drop_duplicates(subset=['PLAYER','GP','Poss'])
putbacks_df2.to_csv('putbacks_23.csv')
putbacks_df.to_csv('putbacks_23_today.csv')

# %%
    
general=[]
    #soup = BeautifulSoup(web_driver.page_source, 'html.parser')
web_driver.quit()
web_driver = webdriver.Safari()
bet_search =  f'https://www.nba.com/stats/players/traditional?PerMode=Totals'
web_driver.get(bet_search)
time.sleep(7)
try:
    web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select").click()
    x = Select(web_driver.find_element("xpath","/html/body/div[1]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select"))
    time.sleep(2)
    x.select_by_visible_text("All")
except:
    pass
soup = BeautifulSoup(web_driver.page_source, 'html.parser')
tab = soup.find("table",{"class":"Crom_table__p1iZz"})
df = pd.read_html(str(tab))[0]
#df['GAME_DATE'] = y + "-" + m + "-" + da
#print(y+m+da)
general.append(df)

# %%
general_df = pd.concat(general)

# %%
web_driver.quit()
