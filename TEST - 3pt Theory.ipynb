# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
shooting_tight = pd.read_csv('shots_tight_23.csv', index_col = 0)
shooting_vtight = pd.read_csv('shots_verytight_23.csv', index_col = 0)
shooting_open = pd.read_csv('shots_open_23.csv', index_col = 0)
shooting_wopen = pd.read_csv('shots_wideopen_23.csv', index_col = 0)
shooting_tight_10 = pd.read_csv('shots_tight_10_23.csv', index_col = 0)
shooting_vtight_10 = pd.read_csv('shots_verytight_10_23.csv', index_col = 0)
shooting_open_10 = pd.read_csv('shots_open_10_23.csv', index_col = 0)
shooting_wopen_10 = pd.read_csv('shots_wideopen_10_23.csv', index_col = 0)

# %%
shooting_tight
# Out:
#               PLAYER TEAM  AGE  GP  G  FREQ%  FGM   FGA   FG%  EFG%  \
# 0       Kevin Durant  PHX   35   1  1   63.6  3.0  14.0  21.4  21.4
# 1       Nikola Jokic  DEN   28   1  1   45.5  7.0  10.0  70.0  70.0
# 2       Devin Booker  PHX   27   1  1   42.9  6.0   9.0  66.7  66.7
# 3       LeBron James  LAL   38   1  1   43.8  4.0   7.0  57.1  57.1
# 4      Rui Hachimura  LAL   25   1  1   70.0  3.0   7.0  42.9  42.9
# ..               ...  ...  ...  .. ..    ...  ...   ...   ...   ...
# 103      Colby Jones  SAC   21   1  1   33.3  0.0   1.0   0.0   0.0
# 104          JT Thor  CHA   21   1  1  100.0  0.0   1.0   0.0   0.0
# 105  Harrison Barnes  SAC   31   1  1   16.7  0.0   1.0   0.0   0.0
# 106     Jordan Nwora  TOR   25   1  1   50.0  0.0   1.0   0.0   0.0
# 107      Leaky Black  CHA   24   1  1   50.0  0.0   1.0   0.0   0.0
#
#      2FG FREQ%  2FGM  2FGA  2FG%  3FG FREQ%  3PM  3PA  3P%   GAME_DATE  \
# 0         63.6   3.0  14.0  21.4        0.0  0.0  0.0    -  2023-10-24
# ...
