# %%
import pandas as pd
import datetime as dt
from bs4 import BeautifulSoup

# %%
#logs
gamelogs = pd.read_csv('gamelogs_min_23.csv', index_col=0)
shooting_ps = pd.read_csv('shooting_formatted_2023.csv', index_col=0)
shooting_logs = pd.read_csv('player_logs_shooting_23.csv', index_col=0)
pass_drives = pd.read_csv('drives_pass_2023_reformat.csv', index_col=0)
rebs_gl = pd.read_csv('player_logs_rebs_23.csv', index_col=0)
ptypes = pd.read_csv('/Users/sethmiller/Documents/NBA/NBA 2022-23 Season/player_types_22.csv', index_col=0)

#def today
shooting_def_tm = pd.read_csv('shooting_def_tm_2023.csv', index_col=0)
shooting_def_pr = pd.read_csv('shooting_def_pr_NBA_2023.csv', index_col=0)
shooting_def_pr1 = pd.read_csv('shooting_def_pr_tm_2023.csv', index_col=0)
shooting_d = pd.read_csv('def_dif_pr_team_2023.csv')
shooting3p_def_tm = pd.read_csv('3p_shooting_def_q2023.csv', index_col=0)
shooting3p_def_pr1 = pd.read_csv('3p_shooting_def_pr2023.csv', index_col=0)
drives_player = pd.read_csv('drives_player_2023.csv', index_col=0)
drives_team_vs = pd.read_csv('drives_team_vs_2023.csv', index_col=0)
rebs_team1 = pd.read_csv('rebs_team_2023.csv', index_col=0)
rebs_players1 = pd.read_csv('rebs_players_2023.csv', index_col=0)
threes_plus2 =  pd.read_csv('threes_plus2_def_23.csv', index_col=0)
threes_plus =  pd.read_csv('threes_plus_def_23.csv', index_col=0)
mid_plus =  pd.read_csv('mid_plus_def_23.csv', index_col=0)
paint_plus =  pd.read_csv('paint_plus_def_23.csv', index_col=0)

dh_logs =  pd.read_csv('dh_logs.csv', index_col=0)
pnr_logs =  pd.read_csv('pnr_logs.csv', index_col=0)
pnp_logs =  pd.read_csv('pnp_logs.csv', index_col=0)
threes_logs =  pd.read_csv('threes_logs.csv', index_col=0)
creator_logs =  pd.read_csv('creator_logs.csv', index_col=0)
secondary_logs =  pd.read_csv('secondary_logs.csv', index_col=0)
sc_logs =  pd.read_csv('sc_logs.csv', index_col=0)

pnp_3logs =  pd.read_csv('pnp_3logs.csv', index_col=0)
threes_3logs =  pd.read_csv('threes_3logs.csv', index_col=0)
creator_3logs =  pd.read_csv('creator_3logs.csv', index_col=0)
secondary_3logs =  pd.read_csv('secondary_3logs.csv', index_col=0)

dh = pd.read_csv('dh_def23.csv', index_col=0)
pnr = pd.read_csv('pnr_def23.csv', index_col=0)
pnp= pd.read_csv('pnp_def23.csv', index_col=0)
threes_d = pd.read_csv('threes_def23.csv', index_col=0)
creator_d = pd.read_csv('creator_def23.csv', index_col=0)
secondary_d = pd.read_csv('secondary_def23.csv', index_col=0)
sc_d = pd.read_csv('sc_def23.csv', index_col=0)

BigMen_d = pd.read_csv('BigMen_def23.csv', index_col=0)
BHReb_d = pd.read_csv('BHReb_def23.csv', index_col=0)
WingReb_d = pd.read_csv('WingReb_def23.csv', index_col=0)

bigmen_logs = pd.read_csv('bigmen_rebs.csv', index_col=0)
wing_logs = pd.read_csv('wings_rebs.csv', index_col=0)
BH_logs = pd.read_csv('BH_rebs.csv',index_col=0)

# %%
downhill23 = pd.read_csv('downhill23.csv', index_col = 0)
picknroll23 = pd.read_csv('picknroll23.csv', index_col = 0)
picknpop23 = pd.read_csv('picknpop23.csv', index_col = 0)
threes23 = pd.read_csv('3pt23.csv', index_col = 0)
creator23 = pd.read_csv('ShotCreator23.csv', index_col = 0)
secondary23 = pd.read_csv('SecondaryShooters23.csv', index_col = 0)
sc23 = pd.read_csv('SecondaryCreators23.csv', index_col = 0)

downhill22 = pd.read_csv('/Users/sethmiller/Documents/NBA/NBA 2022-23 Season/downhill22.csv', index_col = 0)
picknroll22 = pd.read_csv('/Users/sethmiller/Documents/NBA/NBA 2022-23 Season/picknroll22.csv', index_col = 0)
picknpop22 = pd.read_csv('/Users/sethmiller/Documents/NBA/NBA 2022-23 Season/picknpop22.csv', index_col = 0)
threes22 = pd.read_csv('/Users/sethmiller/Documents/NBA/NBA 2022-23 Season/3pt22.csv', index_col = 0)
creator22 = pd.read_csv('/Users/sethmiller/Documents/NBA/NBA 2022-23 Season/ShotCreator22.csv', index_col = 0)
secondary22 = pd.read_csv('/Users/sethmiller/Documents/NBA/NBA 2022-23 Season/SecondaryShooters22.csv', index_col = 0)


#downhill = pd.concat([downhill22[['PLAYER','Downhill']],downhill23[['PLAYER','Downhill']]]).drop_duplicates()
#picknroll = pd.concat([picknroll22[['PLAYER','PickNRoll']],picknroll23[['PLAYER','PickNRoll']]]).drop_duplicates()
#picknpop = pd.concat([picknpop22[['PLAYER','PickNPop']],picknpop23[['PLAYER','PickNPop']]]).drop_duplicates()
#threes = pd.concat([threes22[['PLAYER','3pt']],threes23[['PLAYER','3pt']]]).drop_duplicates()
#creator = pd.concat([creator22[['PLAYER','Shot Creator']],creator23[['PLAYER','Shot Creator']]]).drop_duplicates()
#secondary = pd.concat([secondary22[['PLAYER','Secondary Shooters']],secondary23[['PLAYER','Secondary Shooters']]]).drop_duplicates()


BigMen23 = pd.read_csv('BigMenReb23.csv', index_col = 0)
BHReb23 = pd.read_csv('BHReb23.csv', index_col = 0)
WingReb23 = pd.read_csv('WingReb23.csv', index_col = 0)

# %%
#gamelogs[gamelogs['PLAYER']=='Mikal Bridges']

# %%
from selenium import webdriver
#from webdriver_manager.safari import SafariDriverManager

#safaridriver = "/usr/local/bin/chrome"
#os.environ['webdriver.safari.driver'] = safaridriver
#web_driver = webdriver.Safari(executable_path='/usr/bin/safaridriver')
web_driver = webdriver.Safari()
#driver = webdriver.Chrome('/usr/local/bin/chromedriver')

# selenium 4
#from selenium import webdriver
#from selenium.webdriver.chrome.service import Service as ChromeService
#from webdriver_manager.chrome import ChromeDriverManager

#driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
td = dt.datetime.today().strftime("%Y-%m-%d")
bet_search =  'https://www.rotowire.com/basketball/nba-lineups.php'

web_driver.get(bet_search)
soup = BeautifulSoup(web_driver.page_source, 'html.parser')

# %%
td
# Out:
# '2024-03-29'

# %%
name = [x.get_text() for x in soup.find_all('div', class_='lineup__abbr')]
#names = [s.strip() for s in name]
away = [x.get_text() for x in soup.find_all('a', class_='lineup__team is-visit')]
aways = [s.strip() for s in away]
home = [x.get_text() for x in soup.find_all('a', class_='lineup__team is-home')]
homes = [s.strip() for s in home]

stats = [ homes, aways, ]
key = ['Home','Away']
intial = dict(zip(key, stats))
matchups = pd.DataFrame.from_dict(intial)
todays_tms = pd.DataFrame(name, columns=['TEAM_ABBR'])

sort1 =pd.merge(todays_tms, matchups, how='left', left_on='TEAM_ABBR',right_on='Home')

sort2 =pd.merge(todays_tms, matchups, how='left', left_on='TEAM_ABBR',right_on='Away')

sort1.dropna(inplace=True)
sort2.dropna(inplace=True)

matchups=[sort1,sort2]

team_td = pd.concat(matchups)
team_td.loc[team_td['TEAM_ABBR']!=team_td['Home'], 'OPPONENT']= team_td['Home']
team_td.loc[team_td['TEAM_ABBR']!=team_td['Away'], 'OPPONENT']= team_td['Away']
team_ = team_td[['TEAM_ABBR','OPPONENT']]

# %%
from nba_api.stats.endpoints import commonallplayers
from nba_api.stats.library.parameters import Season
from nba_api.stats.library.parameters import SeasonType


s = commonallplayers.CommonAllPlayers(season='2023-24').get_normalized_dict()

games = s['CommonAllPlayers']
gl_add_23 = pd.DataFrame.from_dict(games)

# %%
gl_add_24 = gl_add_23[gl_add_23['ROSTERSTATUS']==1]

# %%
gl_add_23
# Out:
#       PERSON_ID DISPLAY_LAST_COMMA_FIRST   DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0         76001          Abdelnaby, Alaa       Alaa Abdelnaby             0
# 1         76002         Abdul-Aziz, Zaid      Zaid Abdul-Aziz             0
# 2         76003     Abdul-Jabbar, Kareem  Kareem Abdul-Jabbar             0
# 3            51      Abdul-Rauf, Mahmoud   Mahmoud Abdul-Rauf             0
# 4          1505       Abdul-Wahad, Tariq    Tariq Abdul-Wahad             0
# ...         ...                      ...                  ...           ...
# 4913    1627790              Zizic, Ante           Ante Zizic             0
# 4914      78647                Zoet, Jim             Jim Zoet             0
# 4915      78648               Zopf, Bill            Bill Zopf             0
# 4916    1627826             Zubac, Ivica          Ivica Zubac             1
# 4917      78650              Zunic, Matt           Matt Zunic             0
#
# ...

# %%
players = gl_add_24.loc[gl_add_24['TEAM_ABBREVIATION']!='']
players_ = players[['DISPLAY_FIRST_LAST','TEAM_ABBREVIATION']]
players_.rename(columns={'DISPLAY_FIRST_LAST':'PLAYER','TEAM_ABBREVIATION':'TEAM_ABBR'}, inplace=True)
playing_td = team_.merge(players_).rename(columns={'TEAM_ABBR':'TEAM'})
# Out:
# /var/folders/sj/rsx4zyld6flczf6q6r20b1c80000gn/T/ipykernel_3959/1923986078.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_.rename(columns={'DISPLAY_FIRST_LAST':'PLAYER','TEAM_ABBREVIATION':'TEAM_ABBR'}, inplace=True)

# %%
gamelogs.rename(columns={'PLAYER_NAME':'PLAYER'},inplace=True)

# %%
gamelogs.drop_duplicates(inplace=True)

# %%
gamelogs['OPPONENT'] = gamelogs['MATCHUP'].str.strip().str[-3:]

# %%
players = gamelogs.groupby('PLAYER').agg({'MIN': 'mean','PTS': 'mean','REB': 'mean','AST': 'mean','FG3M': 'mean', 'GAME_DATE': 'count'}).round(2).reset_index()

# %%
players_gen = players.merge(ptypes[['PLAYER','player_roles']], how='left')

# %%
shooting_logs.loc[shooting_logs['player_roles'].isna(), 'player_roles']='None'
players_gen.loc[players_gen['player_roles'].isna(), 'player_roles']='None'

# %%
def get_shooting_prob(df_slice):
    x={}
    
    x['WO_paint_(%)'] = df_slice['2FGM_WO_paint'].sum()/df_slice['2FGA_WO_paint'].sum()
    x['WO_paint_rate'] = (df_slice['2FGA_WO_paint'].sum()/df_slice['MIN'].sum())*36
    x['O_paint_(%)'] = df_slice['2FGM_O_paint'].sum()/df_slice['2FGA_O_paint'].sum()
    x['O_paint_rate'] = (df_slice['2FGA_O_paint'].sum()/df_slice['MIN'].sum())*36
    x['T_paint_(%)'] = df_slice['2FGM_T_paint'].sum()/df_slice['2FGA_T_paint'].sum()
    x['T_paint_rate'] = (df_slice['2FGA_T_paint'].sum()/df_slice['MIN'].sum())*36
    x['VT_paint_(%)'] = df_slice['2FGM_VT_paint'].sum()/df_slice['2FGA_VT_paint'].sum()
    x['VT_paint_rate'] = (df_slice['2FGA_VT_paint'].sum()/df_slice['MIN'].sum())*36
    x['Tot_paint_(%)'] = df_slice['2FGM_paint'].sum()/df_slice['2FGA_paint'].sum()
    x['Tot_paint_rate'] = (df_slice['2FGA_paint'].sum()/df_slice['MIN'].sum())*36
    
    x['WO_mid_(%)'] = df_slice['2FGM_WO_10'].sum()/df_slice['2FGA_WO_10'].sum()
    x['WO_mid_rate'] = (df_slice['2FGA_WO_10'].sum()/df_slice['MIN'].sum())*36
    x['O_mid_(%)'] = df_slice['2FGM_O_10'].sum()/df_slice['2FGA_O_10'].sum()
    x['O_mid_rate'] = (df_slice['2FGA_O_10'].sum()/df_slice['MIN'].sum())*36
    x['T_mid_(%)'] = df_slice['2FGM_T_10'].sum()/df_slice['2FGA_T_10'].sum()
    x['T_mid_rate'] = (df_slice['2FGA_T_10'].sum()/df_slice['MIN'].sum())*36
    x['VT_mid_(%)'] = df_slice['2FGM_VT_10'].sum()/df_slice['2FGA_VT_10'].sum()
    x['VT_mid_rate'] = (df_slice['2FGA_VT_10'].sum()/df_slice['MIN'].sum())*36
    x['Tot_mid_(%)'] = df_slice['2FGM_10'].sum()/df_slice['2FGA_10'].sum()
    x['Tot_mid_rate'] = (df_slice['2FGA_10'].sum()/df_slice['MIN'].sum())*36
    
    x['WO_3P_(%)'] = df_slice['3PM_WO'].sum()/df_slice['3PA_WO'].sum()
    x['WO_3P_rate'] = (df_slice['3PA_WO'].sum()/df_slice['MIN'].sum())*36
    x['O_3P_(%)'] = df_slice['3PM_O'].sum()/df_slice['3PA_O'].sum()
    x['O_3P_rate'] = (df_slice['3PA_O'].sum()/df_slice['MIN'].sum())*36
    x['T_3P_(%)'] = df_slice['3PM_T'].sum()/df_slice['3PA_T'].sum()
    x['T_3P_rate'] = (df_slice['3PA_T'].sum()/df_slice['MIN'].sum())*36
    x['VT_3P_(%)'] = df_slice['3PM_VT'].sum()/df_slice['3PA_VT'].sum()
    x['VT_3P_rate'] = (df_slice['3PA_VT'].sum()/df_slice['MIN'].sum())*36
    x['Tot_3P_(%)'] = df_slice['3PM'].sum()/df_slice['3PA'].sum()
    x['Tot_3P_rate'] = (df_slice['3PA'].sum()/df_slice['MIN'].sum())*36
    x['OPEN_%'] = ((df_slice['3PM_WO'].sum())+(df_slice['3PM_O'].sum()))/((df_slice['3PA_WO'].sum())+(df_slice['3PA_O'].sum()))
    #x['CS_3P_rate'] = (df_slice['3PA_CS'].sum()/df_slice['MIN'].sum())*36
    #x['PU_3P_rate'] = (df_slice['3PA_PULLUP'].sum()/df_slice['MIN'].sum())*36
    
    return pd.Series(x, index=['WO_paint_(%)','WO_paint_rate','O_paint_(%)','O_paint_rate',
                              'T_paint_(%)','T_paint_rate','VT_paint_(%)','VT_paint_rate','Tot_paint_(%)','Tot_paint_rate',
                              'WO_mid_(%)','WO_mid_rate','O_mid_(%)','O_mid_rate',
                              'T_mid_(%)','T_mid_rate','VT_mid_(%)','VT_mid_rate','Tot_mid_(%)','Tot_mid_rate',
                              'WO_3P_(%)','WO_3P_rate','O_3P_(%)','O_3P_rate',
                              'T_3P_(%)','T_3P_rate','VT_3P_(%)','VT_3P_rate','Tot_3P_(%)','Tot_3P_rate','OPEN_%'])

# %%
shooting_players = shooting_logs.groupby(['PLAYER','player_roles','3PM_q','3PM_q2','Mid_q','Paint_q']).apply(get_shooting_prob).round(3).reset_index()
# Out:
# /var/folders/sj/rsx4zyld6flczf6q6r20b1c80000gn/T/ipykernel_3959/915525588.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   x['WO_paint_(%)'] = df_slice['2FGM_WO_paint'].sum()/df_slice['2FGA_WO_paint'].sum()
# /var/folders/sj/rsx4zyld6flczf6q6r20b1c80000gn/T/ipykernel_3959/915525588.py:21: RuntimeWarning: invalid value encountered in scalar divide
#   x['VT_mid_(%)'] = df_slice['2FGM_VT_10'].sum()/df_slice['2FGA_VT_10'].sum()
# /var/folders/sj/rsx4zyld6flczf6q6r20b1c80000gn/T/ipykernel_3959/915525588.py:32: RuntimeWarning: invalid value encountered in scalar divide
#   x['VT_3P_(%)'] = df_slice['3PM_VT'].sum()/df_slice['3PA_VT'].sum()
# /var/folders/sj/rsx4zyld6flczf6q6r20b1c80000gn/T/ipykernel_3959/915525588.py:26: RuntimeWarning: invalid value encountered in scalar divide
#   x['WO_3P_(%)'] = df_slice['3PM_WO'].sum()/df_slice['3PA_WO'].sum()
# ...

# %%
shooting_players.fillna(0, inplace=True)

# %%
shooting_players.columns
# Out:
# Index(['PLAYER', 'player_roles', '3PM_q', '3PM_q2', 'Mid_q', 'Paint_q',
#        'WO_paint_(%)', 'WO_paint_rate', 'O_paint_(%)', 'O_paint_rate',
#        'T_paint_(%)', 'T_paint_rate', 'VT_paint_(%)', 'VT_paint_rate',
#        'Tot_paint_(%)', 'Tot_paint_rate', 'WO_mid_(%)', 'WO_mid_rate',
#        'O_mid_(%)', 'O_mid_rate', 'T_mid_(%)', 'T_mid_rate', 'VT_mid_(%)',
#        'VT_mid_rate', 'Tot_mid_(%)', 'Tot_mid_rate', 'WO_3P_(%)', 'WO_3P_rate',
#        'O_3P_(%)', 'O_3P_rate', 'T_3P_(%)', 'T_3P_rate', 'VT_3P_(%)',
#        'VT_3P_rate', 'Tot_3P_(%)', 'Tot_3P_rate', 'OPEN_%'],
#       dtype='object')

# %%
shooting_players_sm = shooting_players[['PLAYER', 'player_roles', '3PM_q', '3PM_q2', 'Mid_q', 'Paint_q', 'Tot_paint_(%)',
       'Tot_paint_rate','Tot_mid_(%)', 'Tot_mid_rate', 'Tot_3P_(%)', 'Tot_3P_rate', 'OPEN_%']]

# %%
players_tot2 = players_gen.merge(shooting_players_sm, how='left')

# %%
#players_tot2.loc[players_tot2['player_roles']=='None']

# %%
drives_p = drives_player[['PLAYER','drives_q','DRIVES/MIN','DRIVE_SUCCESS_RATE','DRIVES_AST_RATE']]
drives_p.fillna(0, inplace=True)
# Out:
# /var/folders/sj/rsx4zyld6flczf6q6r20b1c80000gn/T/ipykernel_3959/3030765034.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drives_p.fillna(0, inplace=True)

# %%
#drives_p

# %%
players_tot3 = players_tot2.merge(drives_p, how='left')

# %%
players_tot4 =  players_tot3.merge(rebs_players1[['PLAYER','UNCONTESTED_REB%','REB_group']], how='left')

# %%
players_tot5 = players_tot4.merge(playing_td)

# %%
players_tot5.columns
# Out:
# Index(['PLAYER', 'MIN', 'PTS', 'REB', 'AST', 'FG3M', 'GAME_DATE',
#        'player_roles', '3PM_q', '3PM_q2', 'Mid_q', 'Paint_q', 'Tot_paint_(%)',
#        'Tot_paint_rate', 'Tot_mid_(%)', 'Tot_mid_rate', 'Tot_3P_(%)',
#        'Tot_3P_rate', 'OPEN_%', 'drives_q', 'DRIVES/MIN', 'DRIVE_SUCCESS_RATE',
#        'DRIVES_AST_RATE', 'UNCONTESTED_REB%', 'REB_group', 'TEAM', 'OPPONENT'],
#       dtype='object')

# %%
players_3p = players_tot5[['PLAYER','TEAM', 'OPPONENT', 'MIN', 'FG3M', 'GAME_DATE',
       'player_roles', '3PM_q','Tot_3P_(%)', 'OPEN_%','3PM_q2',
       'Tot_3P_rate']]
threes_plus
# Out:
#     OPPONENT      3PM_q  WO_3P_rate  O_3P_rate  T_3P_rate  VT_3P_rate  \
# 0        ATL  Bronze_cs    1.481292   0.818609   0.077963    0.000000
# 1        BKN  Bronze_cs    1.641127   0.169772   0.000000    0.000000
# 2        BOS  Bronze_cs    2.483695   0.479310   0.130721    0.000000
# 3        CHA  Bronze_cs    1.643233   0.589878   0.000000    0.000000
# 4        CHI  Bronze_cs    2.031501   0.586878   0.000000    0.000000
# ..       ...        ...         ...        ...        ...         ...
# 175      SAC    Gold_pu    2.484974   1.610162   0.557851    0.000000
# 176      SAS    Gold_pu    2.958619   1.668028   0.316560    0.036526
# 177      TOR    Gold_pu    2.720956   1.954490   0.549301    0.000000
# 178      UTA    Gold_pu    2.925891   1.474840   0.559012    0.035682
# 179      WAS    Gold_pu    2.163514   1.817864   0.640093    0.012802
#
#      Tot_3P_rate  WO_3P_rate_lg  O_3P_rate_lg  T_3P_rate_lg  VT_3P_rate_lg  \
# ...

# %%
players_3p_2 = players_3p.merge(picknpop23[['PLAYER','PickNPop']], how='left')
players_3p_3 = players_3p_2.merge(creator23[['PLAYER','Shot Creator']], how='left')
players_3p_4 = players_3p_3.merge(threes23[['PLAYER','3pt']], how='left')
players_3p_5 = players_3p_4.merge(secondary23[['PLAYER','Secondary Shooters']], how='left')

# %%
players_3p_ = players_3p_5.merge(threes_plus[['OPPONENT','3PM_q','Three_Open_Rate+','DEF_3q']].rename(columns={'Three_Open_Rate+':'DEF_3_Rate+'}))
players_3p1 = players_3p_.merge(threes_plus2[['OPPONENT','3PM_q2','Three_Open_Rate+_2','DEF_3q2']].rename(columns={'Three_Open_Rate+_2':'DEF_3v2_Rate+'}))

# %%
players_3p2 = players_3p1.merge(shooting3p_def_pr1[['OPPONENT','player_roles','PLUS_SHOT_RATE','OPEN_rank']].rename(columns={'PLUS_SHOT_RATE':'DEF_3P_rate','OPEN_rank':'DEF_3p_rank'}))

# %%
pnp_3logs.head(5)
# Out:
#           PLAYER pnp_3q  trys_pnp  3PM/G_pnp  3PM_O_pnp  3PM_O+_pnp
# 0   Aaron Gordon   BUNS      20.0        0.8       0.55        0.20
# 1   Aaron Gordon  ELITE      14.0        0.5       0.36        0.14
# 2   Aaron Gordon    MID      17.0        0.3       0.24        0.06
# 3  Aaron Holiday   BUNS      19.0        1.0       0.42        0.21
# 4  Aaron Holiday  ELITE      13.0        1.0       0.31        0.23

# %%
pnp
# Out:
#    OPPONENT  Games_pnp  PTS_OVER_pnp  3PM_OVER_pnp  PTS_dif_pnp  \
# 0       ATL       62.0      0.564516          0.27     1.707693
# 1       BKN       60.0      0.383333          0.23    -1.527818
# 2       BOS       59.0      0.457627          0.29    -1.622865
# 3       CHA       64.0      0.578125          0.34     1.964078
# 4       CHI       62.0      0.500000          0.37     0.605988
# 5       CLE       63.0      0.507937          0.30     0.746910
# 6       DAL       54.0      0.518519          0.31     0.188119
# 7       DEN       59.0      0.474576          0.19    -0.213354
# 8       DET       55.0      0.600000          0.35     1.951683
# 9       GSW       44.0      0.568182          0.25     0.506447
# 10      HOU       64.0      0.390625          0.14    -1.394206
# 11      IND       59.0      0.423729          0.17    -0.622623
# 12      LAC       67.0      0.477612          0.24    -0.352776
# 13      LAL       53.0      0.415094          0.38    -1.281625
# ...

# %%
players_3p3 = players_3p2.merge(pnp)
players_3p4 = players_3p3.merge(pnp_3logs)
players_3p5 = players_3p4.merge(creator_d)
players_3p6 = players_3p5.merge(creator_3logs)
players_3p7 = players_3p6.merge(threes_d)
players_3p8 = players_3p7.merge(threes_3logs)
players_3p9 = players_3p8.merge(secondary_d)
players_3p10 = players_3p9.merge(secondary_3logs)

# %%
players_3p10['GAME_DATE'] = td

# %%
players_3p10.loc[players_3p10['PLAYER']=='Lauri Markkanen']
# Out:
#               PLAYER TEAM OPPONENT    MIN  FG3M   GAME_DATE     player_roles  \
# 215  Lauri Markkanen  UTA      HOU  32.65   3.2  2024-03-29  Pick N Pop Bigs
#
#           3PM_q  Tot_3P_(%)  OPEN_%  ... PTS_dif_secondary  \
# 215  Diamond_pu         0.4   0.413  ...         -0.817636
#
#      Paint_plus_secondary Mid_plus_secondary 3p_plus_secondary secondary_q  \
# 215              0.082084          -0.239754          0.144384       ELITE
#
#     secondary_3q  trys_secondary 3PM/G_secondary  3PM_O_secondary  \
# 215          MID            23.0             3.3             0.57
#
#     3PM_O+_secondary
# 215             0.43
#
# [1 rows x 74 columns]

# %%
players_3p2_past = pd.read_csv('players_3p_logs_23.csv')
players_3p2_past = players_3p2_past.loc[:, ~players_3p2_past.columns.str.contains('^Unnamed')]
pd.concat([players_3p2_past,players_3p10]).drop_duplicates(subset=['PLAYER','GAME_DATE'], keep='last').to_csv('players_3p_logs_23.csv', index= False)
#players_3p2.to_csv('players_3p_logs_23.csv')
# Out:
# /var/folders/sj/rsx4zyld6flczf6q6r20b1c80000gn/T/ipykernel_3959/3330336336.py:1: DtypeWarning: Columns (16,22,24,25,26,35,56,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   players_3p2_past = pd.read_csv('players_3p_logs_23.csv')

# %%
from gspread_pandas import Spread, Client
spread = Spread('NBA 2023 v2')
spread.df_to_sheet(players_3p10, index=False,sheet='TODAY 3p2',replace=True)

# %%
players_reb = players_tot5[['PLAYER','TEAM', 'OPPONENT', 'MIN', 'REB', 'GAME_DATE',
       'player_roles', 'UNCONTESTED_REB%', 'REB_group']]
rebs_team1
# Out:
#    OPPONENT REB_group    REB  UNCONTESTED_REB%  UNCONTESTED_REB/36MIN  \
# 0       NYK  Platinum  783.0          0.549170               5.733121
# 1       PHX  Platinum  779.0          0.584082               5.854809
# 2       OKC  Platinum  926.0          0.584233               6.924800
# 3       POR  Platinum  760.0          0.590789               6.717925
# 4       GSW  Platinum  804.0          0.590796               6.676558
# ..      ...       ...    ...               ...                    ...
# 85      WAS    Bronze  555.0          0.790991               3.861415
# 86      DEN    Bronze  459.0          0.797386               3.257355
# 87      CHI    Bronze  514.0          0.801556               3.277211
# 88      LAL    Bronze  516.0          0.808140               3.606400
# 89      CHA    Bronze  589.0          0.818336               3.634383
#
#     REB/36MIN     REB +/-  Reb_rank  UNCONTESTED_Rate+ UC_REBq  as of Date
# ...

# %%
players_reb1 = players_reb.merge(rebs_team1[['OPPONENT','REB_group','REB','UNCONTESTED_REB%','Reb_rank','REB +/-','UNCONTESTED_Rate+','UC_REBq']].rename(columns={'REB':'DEF_TOT_REB','UNCONTESTED_REB%':'DEF_UCReb%','Reb_rank':'Def_rank','REB +/-':'DEF UC +/-'}))

# %%
players_reb2 = players_reb1.merge(BigMen23[['PLAYER','Big Men REB']], how='left')
players_reb3 = players_reb2.merge(BHReb23[['PLAYER','BH Reb']], how='left')
players_reb4 = players_reb3.merge(WingReb23[['PLAYER','Wing Reb']], how='left')
players_reb5 = players_reb4.merge(WingReb_d)
players_reb6 = players_reb5.merge(wing_logs)
players_reb7 = players_reb6.merge(BHReb_d)
players_reb8 = players_reb7.merge(BH_logs)
players_reb9 = players_reb8.merge(BigMen_d)
players_reb10 = players_reb9.merge(bigmen_logs)

# %%
players_reb10['GAME_DATE'] = td

# %%
players_reb10
# Out:
#                  PLAYER TEAM OPPONENT    MIN   REB   GAME_DATE  \
# 0          Aaron Gordon  DEN      MIN  31.46  6.52  2024-03-29
# 1       Christian Braun  DEN      MIN  19.15  3.52  2024-03-29
# 2    Michael Porter Jr.  DEN      MIN  31.67  7.10  2024-03-29
# 3         Peyton Watson  DEN      MIN  18.20  2.86  2024-03-29
# 4        DeAndre Jordan  DEN      MIN  11.28  4.55  2024-03-29
# ..                  ...  ...      ...    ...   ...         ...
# 248     P.J. Washington  DAL      SAC  29.55  5.29  2024-03-29
# 249   Derrick Jones Jr.  DAL      SAC  24.17  3.53  2024-03-29
# 250          Josh Green  DAL      SAC  27.53  3.32  2024-03-29
# 251         Maxi Kleber  DAL      SAC  22.11  3.52  2024-03-29
# 252    Tim Hardaway Jr.  DAL      SAC  29.33  3.61  2024-03-29
#
#           player_roles  UNCONTESTED_REB% REB_group  DEF_TOT_REB  ...  \
# 0       Versitile Bigs          0.552469      Gold        877.0  ...
# ...

# %%
players_reb1_past = pd.read_csv('players_reb_logs_23.csv')
players_reb1_past = players_reb1_past.loc[:, ~players_reb1_past.columns.str.contains('^Unnamed')]
pd.concat([players_reb1_past,players_reb10]).drop_duplicates(subset=['PLAYER','GAME_DATE']).to_csv('players_reb_logs_23.csv', index=False)
#players_reb1.to_csv('players_reb_logs_23.csv')

# %%
from gspread_pandas import Spread, Client
spread = Spread('NBA 2023 v2')
spread.df_to_sheet(players_reb10, index=False,sheet='TODAY REB2',replace=True)

# %%
players_pts = players_tot5[['PLAYER','TEAM', 'OPPONENT', 'MIN', 'PTS','FG3M', 'GAME_DATE',
       'player_roles', '3PM_q2','3PM_q', 'Mid_q', 'Paint_q', 'drives_q',
       'Tot_paint_rate', 'Tot_mid_rate','Tot_3P_rate']]

# %%
#players_pts3.loc[players_pts3['player_roles']=='None']

# %%
players_pts_1 = players_pts.merge(downhill23[['PLAYER','Downhill']], how='left')
players_pts_2 = players_pts_1.merge(picknroll23[['PLAYER','PickNRoll']], how='left')
players_pts_3 = players_pts_2.merge(picknpop23[['PLAYER','PickNPop']], how='left')
players_pts_4 = players_pts_3.merge(threes23[['PLAYER','3pt']], how='left')
players_pts_5 = players_pts_4.merge(creator23[['PLAYER','Shot Creator']], how='left')
players_pts_6 = players_pts_5.merge(secondary23[['PLAYER','Secondary Shooters']], how='left')
players_pts_7 = players_pts_6.merge(sc23[['PLAYER','Secondary Creators']], how='left')

# %%
sc23[['PLAYER','Secondary Creators']]
# Out:
#                   PLAYER Secondary Creators
# 33         Austin Reaves                Yes
# 61           CJ McCollum                Yes
# 69         Cameron Payne                Yes
# 70          Caris LeVert                Yes
# 85            Coby White                Yes
# 89          Cole Anthony                Yes
# 96      Craig Porter Jr.                Yes
# 97      D'Angelo Russell                Yes
# 115       Darius Garland                Yes
# 130      Dennis Schroder                Yes
# 136        Derrick White                Yes
# 168        Fred VanVleet                Yes
# 193    Immanuel Quickley                Yes
# 224          Jalen Green                Yes
# 238         James Harden                Yes
# 278      Jordan Clarkson                Yes
# 285         Jordan Poole                Yes
# 330       Keyonte George                Yes
# 331      Khris Middleton                Yes
# 364      Malcolm Brogdon                Yes
# ...

# %%
players_pts1 = players_pts_7.merge(threes_plus[['OPPONENT','3PM_q','Three_Open_Rate+','DEF_3q']].rename(columns={'Three_Open_Rate+':'DEF_3_Rate+'}),how='left')
players_pts1_ = players_pts1.merge(threes_plus2[['OPPONENT','3PM_q2','Three_Open_Rate+_2','DEF_3q2']].rename(columns={'Three_Open_Rate+_2':'DEF_3v2_Rate+'}),how='left')
players_pts2 = players_pts1_.merge(mid_plus[['OPPONENT','Mid_q','Mid_Open_Rate+','DEF_MIDq']].rename(columns={'Mid_Open_Rate+':'DEF_Mid_Rate+'}),how='left')

# %%
paint = paint_plus.groupby(['OPPONENT'])['Tot_paint_rate'].sum().reset_index()
paint["Paint_rank"] = paint['Tot_paint_rate'].rank(method="dense")
players_pts3 = players_pts2.merge(paint[['OPPONENT','Paint_rank']].rename(columns={'Paint_rank':'DEF_Paint_rank'}),how='left')

# %%
#players_pts4 = players_pts3.merge(dh)
#players_pts5 = players_pts4.merge(picknroll)
#players_pts6 = players_pts5.merge(picknpop)
#players_pts7 = players_pts6.merge(threes)
#players_pts8 = players_pts7.merge(creator)
#players_pts9 = players_pts8.merge(secondary)

# %%
players_pts4 = players_pts3.merge(drives_team_vs[['OPPONENT','drives_q','Drive_rank']].rename(columns={'Drive_rank':'DEF_Drive_rank'}), how='left')

# %%
#players_pts10.loc[players_pts10['player_roles'].isna()]

# %%
players_pts5 = players_pts4.merge(dh,how='left')
players_pts6 = players_pts5.merge(dh_logs,how='left')
players_pts7 = players_pts6.merge(pnr,how='left')
players_pts8 = players_pts7.merge(pnr_logs,how='left')
players_pts9 = players_pts8.merge(pnp,how='left')
players_pts10 = players_pts9.merge(pnp_logs,how='left')
players_pts11 = players_pts10.merge(threes_d,how='left')
players_pts12 = players_pts11.merge(threes_logs,how='left')
players_pts13 = players_pts12.merge(creator_d,how='left')
players_pts14 = players_pts13.merge(creator_logs,how='left')
players_pts15 = players_pts14.merge(sc_d,how='left')
players_pts16 = players_pts15.merge(sc_logs,how='left')
players_pts17 = players_pts16.merge(secondary_d,how='left')
players_pts18 = players_pts17.merge(secondary_logs,how='left')

# %%
players_pts18['GAME_DATE'] = td

# %%
threes_logs.loc[threes_logs['PLAYER']=='Julius Randle']
# Out:
#             PLAYER threes_q  trys_threes  PTS/G_threes  PTS_O_threes  \
# 552  Julius Randle     BUNS         15.0          26.0          0.60
# 553  Julius Randle    ELITE         19.0          22.5          0.32
# 554  Julius Randle      MID         12.0          23.7          0.58
#
#      PTS_O+_threes
# 552           0.27
# 553           0.21
# 554           0.17

# %%
players_pts10.loc[players_pts10['PLAYER']=='Julius Randle']
# Out:
#             PLAYER TEAM OPPONENT    MIN    PTS  FG3M  GAME_DATE  \
# 224  Julius Randle  NYK      SAS  35.44  23.96  1.65         46
#
#         player_roles 3PM_q2    3PM_q  ... PTS_dif_pnp Paint_plus_pnp  \
# 224  Pick N Pop Bigs   Gold  Gold_pu  ...    1.343334       0.104238
#
#     Mid_plus_pnp  3p_plus_pnp  pnp_q  pnp_3q trys_pnp PTS/G_pnp PTS_O_pnp  \
# 224     0.232394     0.439297   BUNS    BUNS     17.0      23.6      0.53
#
#     PTS_O+_pnp
# 224       0.29
#
# [1 rows x 68 columns]

# %%
players_pts4_past = pd.read_csv('players_pts_logs_23.csv')
players_pts4_past = players_pts4_past.loc[:, ~players_pts4_past.columns.str.contains('^Unnamed')]
pd.concat([players_pts4_past,players_pts18]).drop_duplicates(subset=['PLAYER','GAME_DATE'],keep='last').to_csv('players_pts_logs_23.csv', index=False)
#players_pts4.to_csv('players_pts_logs_23.csv')
# Out:
# /var/folders/sj/rsx4zyld6flczf6q6r20b1c80000gn/T/ipykernel_3959/1561109223.py:1: DtypeWarning: Columns (72,79,86,87,94,95,102,103,110,111,123,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   players_pts4_past = pd.read_csv('players_pts_logs_23.csv')

# %%
from gspread_pandas import Spread, Client
spread = Spread('NBA 2023 v2')
spread.df_to_sheet(players_pts18, index=False,sheet='TODAY PTS2',replace=True)

# %%
players_ast = players_tot5[['PLAYER','TEAM', 'OPPONENT', 'MIN', 'AST','GAME_DATE',
       'player_roles' ,'drives_q', 'DRIVES/MIN', 'DRIVE_SUCCESS_RATE',
       'DRIVES_AST_RATE', 'TEAM']]

# %%
def_ast = gamelogs.merge(ptypes[['PLAYER','player_roles']]).groupby(['OPPONENT','player_roles'])['AST'].mean().round(2).reset_index()

# %%
players_ast1 = players_ast.merge(def_ast.rename(columns={'AST':'DEF_AST'}))

# %%
from gspread_pandas import Spread, Client
spread = Spread('NBA 2023')
spread.df_to_sheet(players_ast1, index=False,sheet='TODAY ASSISTS2',replace=True)

# %%
from gspread_pandas import Spread, Client
spread = Spread('NBA 2023')
spread.df_to_sheet(pass_drives, index=False,sheet='Drives Log',replace=True)

from gspread_pandas import Spread, Client
spread = Spread('NBA 2023')
spread.df_to_sheet(rebs_gl, index=False,sheet='Reb Log',replace=True)

from gspread_pandas import Spread, Client
spread = Spread('NBA 2023')
spread.df_to_sheet(shooting_logs, index=False,sheet='Shooting Log',replace=True)
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Input In [1409], in <cell line: 11>()
#       9 from gspread_pandas import Spread, Client
#      10 spread = Spread('NBA 2023')
# ---> 11 spread.df_to_sheet(shooting_logs, index=False,sheet='Shooting Log',replace=True)
#
# File ~/.local/share/virtualenvs/sethmiller-oxBxUwL1/lib/python3.8/site-packages/gspread_pandas/spread.py:744, in Spread.df_to_sheet(self, df, index, headers, start, replace, sheet, raw_columns, freeze_index, freeze_headers, fill_value, add_filter, merge_headers, flatten_headers_sep)
#     739     else:
#     740         raw_columns = find_col_indexes(
#     741             raw_columns, header, start[COL] + index_size
#     742         )
# --> 744 self.update_cells(
#     745     start=start,
#     746     end=end,
#     747     vals=[str(val) for row in df_list for val in row],
# ...

# %%
x = (shooting_logs['3PA_WO'].sum()/shooting_logs['MIN'].sum())*36
y = (shooting_logs['3PA_O'].sum()/shooting_logs['MIN'].sum())*36

# %%
y
# Out:
# 1.879249811492632

# %%
threes_prop_def = shooting_logs.groupby(['OPPONENT']).apply(get_shooting_prob).reset_index()[['OPPONENT','WO_3P_rate','O_3P_rate','T_3P_rate','VT_3P_rate','Tot_3P_rate']]
threes_prop_def['WO_3P_rate_lg'] = x
threes_prop_def['O_3P_rate_lg'] = y
threes_prop_def['Three_Open_Rate+'] = 100*(((threes_prop_def['WO_3P_rate']*.6)+(threes_prop_def['O_3P_rate']*.4))/((threes_prop_def['WO_3P_rate_lg']*.6)+(threes_prop_def['O_3P_rate_lg']*.4)))

# %%
threes_prop_def
# Out:
#    OPPONENT  WO_3P_rate  O_3P_rate  T_3P_rate  VT_3P_rate  Tot_3P_rate  \
# 0       ATL    2.792387   2.002496   0.552306    0.009257     5.356446
# 1       BKN    2.819814   1.964938   0.462526    0.015949     5.263228
# 2       BOS    3.209918   1.921747   0.507461    0.042038     5.681165
# 3       CHA    2.740981   1.933915   0.514695    0.027410     5.217001
# 4       CHI    2.971845   2.167033   0.608081    0.029808     5.776766
# 5       CLE    2.532904   1.944797   0.538320    0.037340     5.053361
# 6       DAL    2.920002   1.802589   0.643553    0.041623     5.407767
# 7       DEN    2.345753   1.747570   0.548073    0.025055     4.666451
# 8       DET    2.332193   1.946048   0.419856    0.042905     4.741002
# 9       GSW    3.011166   1.825456   0.542613    0.023446     5.402681
# 10      HOU    2.659915   1.937850   0.648007    0.033943     5.279716
# 11      IND    2.065552   1.754511   0.543566    0.021139     4.384768
# ...

# %%
threes_plus.loc[threes_plus['3PM_q']=='Platinum'].sort_values(by='Three_Open_Rate+')
# Out:
# Empty DataFrame
# Columns: [OPPONENT, 3PM_q, WO_3P_rate, O_3P_rate, T_3P_rate, VT_3P_rate, Tot_3P_rate, WO_3P_rate_lg, O_3P_rate_lg, T_3P_rate_lg, VT_3P_rate_lg, Tot_3P_rate_lg, Three_Open_Rate+, DEF_3q]
# Index: []

# %%
def_ast = gamelogs.merge(ptypes[['PLAYER','player_roles']]).groupby(['OPPONENT','player_roles'])['AST'].mean().round(2).reset_index()

# %%
def_ast
# Out:
#     OPPONENT             player_roles   AST
# 0        ATL                3pt Wings  1.56
# 1        ATL                Glue Guys  2.05
# 2        ATL              Non-Offense  1.55
# 3        ATL          Pick N Pop Bigs  2.05
# 4        ATL    Primary Ball Handlers  7.47
# ..       ...                      ...   ...
# 325      WAS             Role Big Men  1.55
# 326      WAS                 Role G/W  3.15
# 327      WAS        Run Around Guards  1.84
# 328      WAS  Secondary Ball Handlers  5.13
# 329      WAS           Versitile Bigs  3.72
#
# [330 rows x 3 columns]
